# %% [markdown]
# <a href="https://colab.research.google.com/github/galihnurkanta/123123/blob/main/PersiapanDatMin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
import pandas as pd, matplotlib.pyplot as plt, seaborn as sns, numpy as np
import matplotlib.cm as cm
from collections import Counter
plt.style.use('bmh'); sns.set()

# %%
#Import csv data
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a5144dbb-d188-4242-a612-a1b2fe69531e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a5144dbb-d188-4242-a612-a1b2fe69531e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('208baru.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-715de32b0b6e> in <module>
# ----> 1 df=pd.read_csv('208baru.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df3 = pd.read_excel('bps-file.xlsx')
df3
# Out:
#                               nama_variabel nama_variabel_turunan  nama_tahun  \
# 0    Jumlah Perusahaan Menurut 2-digit KBLI                 Mikro        2010
# 1    Jumlah Perusahaan Menurut 2-digit KBLI                 Mikro        2010
# 2    Jumlah Perusahaan Menurut 2-digit KBLI                 Mikro        2010
# 3    Jumlah Perusahaan Menurut 2-digit KBLI                 Mikro        2010
# 4    Jumlah Perusahaan Menurut 2-digit KBLI                 Mikro        2010
# ..                                      ...                   ...         ...
# 307  Jumlah Perusahaan Menurut 2-digit KBLI                 Kecil        2015
# 308  Jumlah Perusahaan Menurut 2-digit KBLI                 Kecil        2015
# 309  Jumlah Perusahaan Menurut 2-digit KBLI                 Kecil        2015
# 310  Jumlah Perusahaan Menurut 2-digit KBLI                 Kecil        2015
# 311  Jumlah Perusahaan Menurut 2-digit KBLI                 Kecil        2015
#
# ...

# %%
#Sukses read csv untuk pandas <1.3.0
df = pd.read_csv('bps-file.csv',error_bad_lines=False)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-7d06fbae20cd> in <module>
#       1 #Sukses read csv untuk pandas <1.3.0
# ----> 2 df = pd.read_csv('bps-file.csv',error_bad_lines=False)
#       3 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df11 = pd.read_csv('bps-file.csv',on_bad_lines='skip')

# %%
df11
# Out:
#     nama_variabel;nama_variabel_turunan;nama_tahun;nama_turunan_tahun;data_content;nama_item_vertical_variabel
# 0    Jumlah Perusahaan Menurut 2-digit KBLI;Mikro;2...
# 1    Jumlah Perusahaan Menurut 2-digit KBLI;Mikro;2...
# 2    Jumlah Perusahaan Menurut 2-digit KBLI;Mikro;2...
# 3    Jumlah Perusahaan Menurut 2-digit KBLI;Mikro;2...
# 4    Jumlah Perusahaan Menurut 2-digit KBLI;Mikro;2...
# ..                                                 ...
# 223  Jumlah Perusahaan Menurut 2-digit KBLI;Kecil;2...
# 224  Jumlah Perusahaan Menurut 2-digit KBLI;Kecil;2...
# 225  Jumlah Perusahaan Menurut 2-digit KBLI;Kecil;2...
# 226  Jumlah Perusahaan Menurut 2-digit KBLI;Kecil;2...
# 227  Jumlah Perusahaan Menurut 2-digit KBLI;Kecil;2...
#
# [228 rows x 1 columns]

# %%
path = 'bps-file.csv'
#print(open(path).read())
data = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-72-1b75757c6184> in <module>
#       1 path = 'bps-file.csv'
#       2 #print(open(path).read())
# ----> 3 data = pd.read_csv(path)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-38-d5df0069828e> in <module>
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms)
#     103       force_remount=force_remount,
#     104       timeout_ms=timeout_ms,
# --> 105       ephemeral=True)
#     106
#     107
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral)
#     118   if ephemeral:
#     119     _message.blocking_request(
# --> 120         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     121
#     122   mountpoint = _os.path.expanduser(mountpoint)
#
# ...

# %%
df = pd.read_csv('mnist_test.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-fdbd59450a84> in <module>
# ----> 1 df = pd.read_csv('mnist_test.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['208baru (3).csv']))
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-dbad87a43082> in <module>
#       1 import pandas as pd
#       2 import io
# ----> 3 df = pd.read_csv(io.BytesIO(uploaded['208baru (3).csv']))
#       4 print(df)
#
# KeyError: '208baru (3).csv'

# %%
df
# Out:
#                   NIK                    NAMA JENIS_KELAMIN TANGGAL_LAHIR  \
# 0    1806211005040002           miki harnanda             L    2004-05-10
# 1    1806211101040001              arda billy             L    2004-01-11
# 2    3671084901900003         EKA NURMALASARI             P    1990-01-09
# 3    3671085403880003  PRAHESTI TIRTA SAFITRI     Perempuan    1988-03-14
# 4    3671094709040001           SEPTI NURAINI             P    2004-09-07
# ..                ...                     ...           ...           ...
# 144  1275042205820006        FRANCIUS DAMANIK           NaN           NaN
# 145  3273206810840009           EVA DAMAYANTI           NaN           NaN
# 146  3674020812810007                SAMSUDIN           NaN           NaN
# 147  3671114603980006      RESTU DWI ALAWIYAH           NaN           NaN
# 148  3674026604980003         MIFTAHUL JANNAH           NaN           NaN
#
#      UMUR INSTANSI_PEKERJAAN        JENIS_PEKERJAAN KODE_KATEGORI  \
# ...
